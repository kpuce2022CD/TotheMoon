# %%
from common_words import CommonWords

# %%
commonwords = CommonWords()

list = commonwords.word_count_list_krwordrank(['5aPOr-8qRFw.xlsx','iPIiI5oxKNM.xlsx','TYT15A1ZzQQ.xlsx','uyeaOv3lZc4.xlsx']).common_word_list(3)
print(list)
# Out:
# ['많이', '영상', '너무', '이번', '내가', 'ㅋㅋ', '남자', '조합', '이거', '있는', '아닌', '진짜', '아니', 'ㅠㅠ', '계속', '좋아', '이렇게', '좋겠다', '제발', '사람', '점점', '보고', '근데', '그냥', '다음', '여기', '뭔가', '보는', 'ㄹㅇ', '하는', '언제', '한번', '같아', '이런', '무슨', '지금', '같음', '느낌', '보면', '우리', '이제', 'ㅎㅎ', '알았', '보니', '좋다', '항상', '어떻게', '다들', '생각', '가는', '그런', '하나', '어디', '좋은', '좋네', '보기', '올라', '응원', '올려']

# %%
list = commonwords.word_count_list_soynlp(['5aPOr-8qRFw.xlsx','iPIiI5oxKNM.xlsx','TYT15A1ZzQQ.xlsx','uyeaOv3lZc4.xlsx']).common_word_list(3)
print(list)
# Out:
# ['영상', '조합', '감사', '잘', '사람', '시작', '바', '맛', '망', '코', '강', '진짜', '왜', '것', '좋아', '안', '제', '오늘', '처음', '뭔', '때', '사랑', '느낌', '못', '생각', '얼굴', '이번', '다음', '남자', '첨', '저번', '맨', '기대', '이름', '중간', '너', '앞', '모습', '재미', '끝', '아직', '응원', '미안', '댓글', '답답', '똑', '명', '나이']

# %%
list = commonwords.word_count_list_konlpy(['5aPOr-8qRFw.xlsx','iPIiI5oxKNM.xlsx','TYT15A1ZzQQ.xlsx','uyeaOv3lZc4.xlsx']).common_word_list(3)
print(list)
# Out:
# ['요', '복', '새해', '영상', '조합', '이번', '남자', '등', '덕분', '내', '진짜', '거', '그냥', '항상', '시즌', '걸', '게임', '가요', '때', '보고', '사람', '공략', '도전', '더', '오늘', '자꾸', '개', '오', '채널', '모든', '무조건', '이해', '처음', '축복', '꿀', '계속', '알', '생각', '하나', '시작', '코', '이', '판', '맛', '개꿀', '것', '이제', '눈', '설날', '선생님', '설명', '초반', '여기', '짐', '정도', '소리', '연', '뭐', '몇몇', '저', '억지로', '욕심', '케', '말', '의', '쇼', '난', '또', '깜짝', '지금', '해', '힘', '가면', '저번', '달', '식', '바로', '년', '팀', '뚜', '존나', '급', '듯', '주', '때문', '점', '마', '못', '지네', '이유', '레벨', '당신', '선택', '젠', '어제', '점점', '치', '키', '대체', '좀', '네', '상황', '정말', '하루', '글', '개인', '잘못', '일', '갑자기', '일반', '얼마', '다음', '이건', '왜', '감', '피', '관리', '빡세', '터', '게', '다가', '나중', '각', '무지', '바', '최근', '용', '전', '배', '셧', '그거', '상대', '다른', '완전', '형님', '마지막', '체', '한번', '보이', '입장', '안', '넹', '가지', '요즘', '킹', '웃기', '나', '편', '컨셉', '이의', '기네', '분', '왤케', '사랑', '줄', '느낌', '왜케', '제발', '수', '얼굴', '정상', '머', '뭔가', '진심', '입', '중', '역대', '레전드', '원래', '약간', '중간', '너', '누가', '예능', '보', '언제', '데', '바람
# ...
